# %% [markdown]
# ## 1. Introduction
#
# In this codelab you'll learn the basic "Hello World" of machine learning where, instead of programming explicit rules in a language such as Java or C++, you'll build a system that is trained on data to infer the rules that determine a relationship between numbers.
#
# Consider the following problem: You're building a system that performs activity recognition for fitness tracking. You might have access to the speed at which a person is moving, and attempt to infer their activity based on this speed using a conditional:
#
# <img align="middle" src="image/walking.png"/>

# %% [raw]
# if(speed<4){
#   status=WALKING;
# }

# %% [markdown]
# You could extend this to running with another condition:
#
# <img align="middle" src="image/Running.png"/>

# %% [raw]
# if(speed<4){
#     status=WALKING;
# } else {
#     status=RUNNING;
# }

# %% [markdown]
# In a final condition you could similarly detect cycling:
#
# <img align="middle" src="image/Cycleing.png"/>

# %% [raw]
# if(speed<4){
#     status=WALKING;
# } else if(speed<12){
#     status=RUNNING;
# } else {
#     status=BIKING;
# }

# %% [markdown]
# Now consider what happens when you want to include an activity like golf? Suddenly it's less obvious how to create a rule to determine the activity.
#
# <img align="middle" src="image/glof.png"/>

# %% [raw]
# // Now what?

# %% [markdown]
# It's extremely difficult to write a program (expressed in code) that will give us the golfing activity. So what do you do? That's where machine learning can be used to solve the problem!

# %% [markdown]
# ### 2. What is machine learning?

# %% [markdown]
# In the previous section you saw a problem where, when trying to determine the fitness activity of a user, you hit limitations in what you could write code to achieve.
#
# Consider building applications in the traditional manner as represented in the following diagram:
#
# <img align="middle" src="image/traditional manner.png"/>
#
# You express `rules` in a programming language. These act on `data` and your program provides `answers`. In the case of the activity detection, the rules (the code you wrote to define types of activities) acted upon the data (the person's movement speed) in order to find an answer -- the return value from the function for determining the activity status of the user (whether they were walking, running, biking, etc.).
#
# The process for detecting this activity status via Machine Learning is very similar -- only the axes are different:
#
# <img align="middle" src="image/Tm.png"/>
#
#
# Instead of trying to define the rules and express them in a programming language, you provide the answers (typically called `labels`) along with the data, and the machine will `infer` the rules that determine the relationship between the answers and the data. For example, our activity detection scenario might look like this in a machine learning context:
#
# <img align="middle" src="image/Data.png"/>
#
# We gather lots of data, and label it to effectively say "This is what walking looks like", "This is what running looks like" etc. Then, the computer can infer the rules that determine, from the data, what the distinct patterns that denote a particular activity are.
#
# Beyond being an alternative method to programming this scenario, this also gives you the ability to open up new scenarios, such as the golfing one that may not have been possible under the rules-based traditional programming approach.
#
# In traditional programming your code compiles into a binary that is typically called a program. In machine learning, the item you create from the data and labels is called a **model**.
#
# So if we go back to this diagram:
# <img align="middle" src="image/model.png"/>
# Consider the result of this to be a model, which at runtime is used like this:
# <img align="middle" src="image/modle1.png"/>
#
# You will pass the model some data, and the model will use the rules it inferred from the training to come up with a prediction -- i.e. "That data looks like walking", "That data looks like biking" etc.
#
# In the next section you'll start coding, building a very simple "Hello World" model which will have most of the building blocks that can be used in any Machine Learning Scenario!

# %% [markdown]
# ## 3. Before you start...
#
# In the next section you'll create a very simple machine learned model that determines patterns in a set of data using machine learning techniques and a neural network.
#
# If you've never created a Machine Learning model using TensorFlow, I'd strongly recommend you use Google Colaboratory, a browser-based environment that contains all the required dependencies. You can find the code for the rest of this lab running in a Colab.
#
# Otherwise, the main language you will use for training models is Python, so you will need to have that installed. In addition to that you'll also need TensorFlow. Details on installing it are [here](https://www.tensorflow.org/install). You'll also need the [numpy](https://numpy.org/) library.

# %% [markdown]
# ## 4. Create your first machine-learned model
#
#
# Consider the following sets of numbers. Can you see the relationship between them?
#
# |X:| -1 |  0| 1|  2 |3| 4|
# |--|--|--|--|--|--|--|
# |Y:|-2 |1 | 4|7|10|13|
#
#
#
# Like every first app you should start with something super simple that shows the overall scaffolding for how your code works.
#
# In the case of creating neural networks, the sample I like to use is one where it learns the relationship between two numbers. So, for example, if you were writing code for a function like this, you already know the 'rules' --
#
#
# ```
# float my_function(float x){
#     float y = (3 * x) + 1;
#     return y;
# }
# ```
#
# So how would you train a neural network to do the equivalent task? Using data! By feeding it with a set of Xs, and a set of Ys, it should be able to figure out the relationship between them.
#
# This is obviously a very different paradigm than what you might be used to, so let's step through it piece by piece.
#
#
# ## Imports
#
# Let's start with our imports. Here we are importing TensorFlow and calling it tf for ease of use.
#
# We then import a library called numpy, which helps us to represent our data as lists easily and quickly.
#
# The framework for defining a neural network as a set of Sequential layers is called keras, so we import that too.

# %%
import tensorflow as tf
import numpy as np
from tensorflow import keras
# Out:
# WARNING:tensorflow:From c:\users\esambatireddyprasad\appdata\local\programs\python\python39\lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %% [markdown]
# ## Define and Compile the Neural Network
#
# Next we will create the simplest possible neural network. It has 1 layer, and that layer has 1 neuron, and the input shape to it is just 1 value.

# %%
model = tf.keras.Sequential([keras.layers.Dense(units=1, input_shape=[1])])
# Out:
# WARNING:tensorflow:From c:\users\esambatireddyprasad\appdata\local\programs\python\python39\lib\site-packages\keras\src\backend.py:873: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.

# %% [markdown]
# Now we compile our Neural Network. When we do so, we have to specify 2 functions, a loss and an optimizer.
#
# If you've seen lots of math for machine learning, here's where it's usually used, but in this case it's nicely encapsulated in functions for you. But what happens here -- let's explain...
#
# We know that in our function, the relationship between the numbers is y=3x+1.
#
# When the computer is trying to 'learn' that, it makes a guess...maybe y=10x+10. The `LOSS` function measures the guessed answers against the known correct answers and measures how well or how badly it did.
#
# It then uses the `OPTIMIZER` function to make another guess. Based on how the loss function went, it will try to minimize the loss. At that point maybe it will come up with somehting like y=5x+5, which, while still pretty bad, is closer to the correct result (i.e. the loss is lower)
#
# It will repeat this for the number of `EPOCHS` which you will see shortly. But first, here's how we tell it to use `MEAN SQUARED ERROR` for the loss and `STOCHASTIC GRADIENT DESCENT` for the optimizer. You don't need to understand the math for these yet, but you can see that they work! :)
#
# Over time you will learn the different and appropriate loss and optimizer functions for different scenarios.

# %%
model.compile(optimizer='sgd', loss='mean_squared_error')
# Out:
# WARNING:tensorflow:From c:\users\esambatireddyprasad\appdata\local\programs\python\python39\lib\site-packages\keras\src\optimizers\__init__.py:309: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.

# %% [markdown]
# ## Providing the Data
#
# Next up we'll feed in some data. In this case we are taking 6 xs and 6ys. You can see that the relationship between these is that y=2x-1, so where x = -1, y=-3 etc. etc.
#
# A python library called 'Numpy' provides lots of array type data structures that are a defacto standard way of doing it. We declare that we want to use these by specifying the values asn an np.array[]

# %%
xs = np.array([-1.0, 0.0, 1.0, 2.0, 3.0, 4.0], dtype=float)
ys = np.array([-2.0, 1.0, 4.0, 7.0, 10.0, 13.0], dtype=float)

# %% [markdown]
# # Training the Neural Network
#
# The process of training the neural network, where it 'learns' the relationship between the Xs and Ys is in the **model.fit**  call. This is where it will go through the loop we spoke about above, making a guess, measuring how good or bad it is (aka the loss), using the opimizer to make another guess etc. It will do it for the number of epochs you specify. When you run this code, you'll see the loss on the right hand side.

# %%
model.fit(xs, ys, epochs=500)
# Out:
# Epoch 1/500
# WARNING:tensorflow:From c:\users\esambatireddyprasad\appdata\local\programs\python\python39\lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# 1/1 [==============================] - 16s 16s/step - loss: 53.8301
# Epoch 2/500
# 1/1 [==============================] - 0s 12ms/step - loss: 42.3513
# Epoch 3/500
# 1/1 [==============================] - 0s 13ms/step - loss: 33.3202
# Epoch 4/500
# 1/1 [==============================] - 0s 11ms/step - loss: 26.2150
# Epoch 5/500
# 1/1 [==============================] - 0s 10ms/step - loss: 20.6250
# Epoch 6/500
# 1/1 [==============================] - 0s 11ms/step - loss: 16.2270
# Epoch 7/500
# 1/1 [==============================] - 0s 13ms/step - loss: 12.7669
# Epoch 8/500
# 1/1 [==============================] - 0s 12ms/step - loss: 10.0447
# Epoch 9/500
# 1/1 [==============================] - 0s 10ms/step - loss: 7.9029
# Epoch 10/500
# 1/1 [==============================] - 0s 56ms/step - loss: 6.2179
# Epoch 11/500
# 1/1 [==============================] - 0s 8ms/step - loss: 4.8922
# Epoch 12/500
# 1/1 [==============================] - 0s 6ms/step - loss: 3.8492
# Epoch 13/500
# 1/1 [==============================] - 0s 8ms/step - loss: 3.0286
# Epoch 14/500
# 1/1 [==============================] - 0s 7ms/step - loss: 2.3830
# Epoch 15/500
# 1/1 [==============================] - 0s 9ms/step - loss: 1.8750
# Epoch 16/500
# 1/1 [==============================] - 0s 8ms/step - loss: 1.4754
# Epoch 17/500
# 1/1 [==============================] - 0s 8ms/step - loss: 1.1610
# Epoch 18/500
# 1/1 [==============================] - 0s 9ms/step - loss: 0.9136
# Epoch 19/500
# 1/1 [==============================] - 0s 7ms/step - loss: 0.7190
# Epoch 20/500
# 1/1 [==============================] - 0s 6ms/step - loss: 0.5659
# Epoch 21/500
# 1/1 [==============================] - 0s 8ms/step - loss: 0.4454
# Epoch 22/500
# 1/1 [==============================] - 0s 8ms/step - loss: 0.3506
# Epoch 23/500
# 1/1 [==============================] - 0s 7ms/step - loss: 0.2761
# Epoch 24/500
# 1/1 [==============================] - 0s 7ms/step - loss: 0.2174
# Epoch 25/500
# 1/1 [==============================] - 0s 7ms/step - loss: 0.1712
# Epoch 26/500
# 1/1 [==============================] - 0s 8ms/step - loss: 0.1349
# Epoch 27/500
# 1/1 [==============================] - 0s 8ms/step - loss: 0.1063
# Epoch 28/500
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0838
# Epoch 29/500
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0661
# Epoch 30/500
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0522
# Epoch 31/500
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0412
# Epoch 32/500
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0326
# Epoch 33/500
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0258
# Epoch 34/500
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0205
# Epoch 35/500
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0162
# Epoch 36/500
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0129
# Epoch 37/500
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0103
# Epoch 38/500
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0083
# Epoch 39/500
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0066
# Epoch 40/500
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0054
# Epoch 41/500
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0044
# Epoch 42/500
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0036
# Epoch 43/500
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0029
# Epoch 44/500
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0024
# Epoch 45/500
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0020
# Epoch 46/500
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0017
# Epoch 47/500
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0015
# Epoch 48/500
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0013
# Epoch 49/500
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0011
# Epoch 50/500
# 1/1 [==============================] - 0s 6ms/step - loss: 9.9251e-04
# Epoch 51/500
# 1/1 [==============================] - 0s 6ms/step - loss: 8.9047e-04
# Epoch 52/500
# 1/1 [==============================] - 0s 7ms/step - loss: 8.0795e-04
# Epoch 53/500
# 1/1 [==============================] - 0s 7ms/step - loss: 7.4082e-04
# Epoch 54/500
# 1/1 [==============================] - 0s 8ms/step - loss: 6.8584e-04
# Epoch 55/500
# 1/1 [==============================] - 0s 7ms/step - loss: 6.4046e-04
# Epoch 56/500
# 1/1 [==============================] - 0s 7ms/step - loss: 6.0270e-04
# Epoch 57/500
# 1/1 [==============================] - 0s 7ms/step - loss: 5.7095e-04
# Epoch 58/500
# 1/1 [==============================] - 0s 6ms/step - loss: 5.4399e-04
# Epoch 59/500
# 1/1 [==============================] - 0s 8ms/step - loss: 5.2083e-04
# Epoch 60/500
# 1/1 [==============================] - 0s 8ms/step - loss: 5.0070e-04
# Epoch 61/500
# 1/1 [==============================] - 0s 7ms/step - loss: 4.8299e-04
# Epoch 62/500
# 1/1 [==============================] - 0s 6ms/step - loss: 4.6724e-04
# Epoch 63/500
# 1/1 [==============================] - 0s 6ms/step - loss: 4.5305e-04
# Epoch 64/500
# 1/1 [==============================] - 0s 6ms/step - loss: 4.4013e-04
# Epoch 65/500
# 1/1 [==============================] - 0s 6ms/step - loss: 4.2825e-04
# Epoch 66/500
# 1/1 [==============================] - 0s 27ms/step - loss: 4.1722e-04
# Epoch 67/500
# 1/1 [==============================] - 0s 8ms/step - loss: 4.0689e-04
# Epoch 68/500
# 1/1 [==============================] - 0s 6ms/step - loss: 3.9715e-04
# Epoch 69/500
# 1/1 [==============================] - 0s 6ms/step - loss: 3.8791e-04
# Epoch 70/500
# 1/1 [==============================] - 0s 6ms/step - loss: 3.7908e-04
# Epoch 71/500
# 1/1 [==============================] - 0s 6ms/step - loss: 3.7062e-04
# Epoch 72/500
# 1/1 [==============================] - 0s 7ms/step - loss: 3.6248e-04
# Epoch 73/500
# 1/1 [==============================] - 0s 7ms/step - loss: 3.5461e-04
# Epoch 74/500
# 1/1 [==============================] - 0s 6ms/step - loss: 3.4700e-04
# Epoch 75/500
# 1/1 [==============================] - 0s 7ms/step - loss: 3.3962e-04
# Epoch 76/500
# 1/1 [==============================] - 0s 7ms/step - loss: 3.3244e-04
# Epoch 77/500
# 1/1 [==============================] - 0s 9ms/step - loss: 3.2545e-04
# Epoch 78/500
# 1/1 [==============================] - 0s 6ms/step - loss: 3.1864e-04
# Epoch 79/500
# 1/1 [==============================] - 0s 8ms/step - loss: 3.1199e-04
# Epoch 80/500
# 1/1 [==============================] - 0s 8ms/step - loss: 3.0551e-04
# Epoch 81/500
# 1/1 [==============================] - 0s 7ms/step - loss: 2.9917e-04
# Epoch 82/500
# 1/1 [==============================] - 0s 6ms/step - loss: 2.9298e-04
# Epoch 83/500
# 1/1 [==============================] - 0s 7ms/step - loss: 2.8692e-04
# Epoch 84/500
# 1/1 [==============================] - 0s 6ms/step - loss: 2.8100e-04
# Epoch 85/500
# 1/1 [==============================] - 0s 6ms/step - loss: 2.7520e-04
# Epoch 86/500
# 1/1 [==============================] - 0s 6ms/step - loss: 2.6954e-04
# Epoch 87/500
# 1/1 [==============================] - 0s 5ms/step - loss: 2.6398e-04
# Epoch 88/500
# 1/1 [==============================] - 0s 6ms/step - loss: 2.5855e-04
# Epoch 89/500
# 1/1 [==============================] - 0s 6ms/step - loss: 2.5323e-04
# Epoch 90/500
# 1/1 [==============================] - 0s 7ms/step - loss: 2.4802e-04
# Epoch 91/500
# 1/1 [==============================] - 0s 6ms/step - loss: 2.4292e-04
# Epoch 92/500
# 1/1 [==============================] - 0s 8ms/step - loss: 2.3792e-04
# Epoch 93/500
# 1/1 [==============================] - 0s 6ms/step - loss: 2.3304e-04
# Epoch 94/500
# 1/1 [==============================] - 0s 7ms/step - loss: 2.2825e-04
# Epoch 95/500
# 1/1 [==============================] - 0s 6ms/step - loss: 2.2356e-04
# Epoch 96/500
# 1/1 [==============================] - 0s 7ms/step - loss: 2.1896e-04
# Epoch 97/500
# 1/1 [==============================] - 0s 7ms/step - loss: 2.1446e-04
# Epoch 98/500
# 1/1 [==============================] - 0s 6ms/step - loss: 2.1006e-04
# Epoch 99/500
# 1/1 [==============================] - 0s 6ms/step - loss: 2.0574e-04
# Epoch 100/500
# 1/1 [==============================] - 0s 6ms/step - loss: 2.0152e-04
# Epoch 101/500
# 1/1 [==============================] - 0s 6ms/step - loss: 1.9738e-04
# Epoch 102/500
# 1/1 [==============================] - 0s 6ms/step - loss: 1.9332e-04
# Epoch 103/500
# 1/1 [==============================] - 0s 7ms/step - loss: 1.8935e-04
# Epoch 104/500
# 1/1 [==============================] - 0s 8ms/step - loss: 1.8546e-04
# Epoch 105/500
# 1/1 [==============================] - 0s 8ms/step - loss: 1.8165e-04
# Epoch 106/500
# 1/1 [==============================] - 0s 7ms/step - loss: 1.7792e-04
# Epoch 107/500
# 1/1 [==============================] - 0s 7ms/step - loss: 1.7426e-04
# Epoch 108/500
# 1/1 [==============================] - 0s 6ms/step - loss: 1.7069e-04
# Epoch 109/500
# 1/1 [==============================] - 0s 7ms/step - loss: 1.6718e-04
# Epoch 110/500
# 1/1 [==============================] - 0s 7ms/step - loss: 1.6375e-04
# Epoch 111/500
# 1/1 [==============================] - 0s 7ms/step - loss: 1.6038e-04
# Epoch 112/500
# 1/1 [==============================] - 0s 6ms/step - loss: 1.5709e-04
# Epoch 113/500
# 1/1 [==============================] - 0s 6ms/step - loss: 1.5386e-04
# Epoch 114/500
# 1/1 [==============================] - 0s 6ms/step - loss: 1.5070e-04
# Epoch 115/500
# 1/1 [==============================] - 0s 7ms/step - loss: 1.4761e-04
# Epoch 116/500
# 1/1 [==============================] - 0s 7ms/step - loss: 1.4457e-04
# Epoch 117/500
# 1/1 [==============================] - 0s 6ms/step - loss: 1.4160e-04
# Epoch 118/500
# 1/1 [==============================] - 0s 7ms/step - loss: 1.3869e-04
# Epoch 119/500
# 1/1 [==============================] - 0s 7ms/step - loss: 1.3584e-04
# Epoch 120/500
# 1/1 [==============================] - 0s 7ms/step - loss: 1.3306e-04
# Epoch 121/500
# 1/1 [==============================] - 0s 7ms/step - loss: 1.3032e-04
# Epoch 122/500
# 1/1 [==============================] - 0s 7ms/step - loss: 1.2765e-04
# Epoch 123/500
# 1/1 [==============================] - 0s 6ms/step - loss: 1.2502e-04
# Epoch 124/500
# 1/1 [==============================] - 0s 6ms/step - loss: 1.2246e-04
# Epoch 125/500
# 1/1 [==============================] - 0s 6ms/step - loss: 1.1994e-04
# Epoch 126/500
# 1/1 [==============================] - 0s 6ms/step - loss: 1.1748e-04
# Epoch 127/500
# 1/1 [==============================] - 0s 6ms/step - loss: 1.1507e-04
# Epoch 128/500
# 1/1 [==============================] - 0s 6ms/step - loss: 1.1270e-04
# Epoch 129/500
# 1/1 [==============================] - 0s 6ms/step - loss: 1.1039e-04
# Epoch 130/500
# 1/1 [==============================] - 0s 9ms/step - loss: 1.0812e-04
# Epoch 131/500
# 1/1 [==============================] - 0s 7ms/step - loss: 1.0590e-04
# Epoch 132/500
# 1/1 [==============================] - 0s 6ms/step - loss: 1.0372e-04
# Epoch 133/500
# 1/1 [==============================] - 0s 7ms/step - loss: 1.0159e-04
# Epoch 134/500
# 1/1 [==============================] - 0s 8ms/step - loss: 9.9506e-05
# Epoch 135/500
# 1/1 [==============================] - 0s 7ms/step - loss: 9.7462e-05
# Epoch 136/500
# 1/1 [==============================] - 0s 7ms/step - loss: 9.5461e-05
# Epoch 137/500
# 1/1 [==============================] - 0s 6ms/step - loss: 9.3498e-05
# Epoch 138/500
# 1/1 [==============================] - 0s 5ms/step - loss: 9.1579e-05
# Epoch 139/500
# 1/1 [==============================] - 0s 6ms/step - loss: 8.9697e-05
# Epoch 140/500
# 1/1 [==============================] - 0s 7ms/step - loss: 8.7854e-05
# Epoch 141/500
# 1/1 [==============================] - 0s 6ms/step - loss: 8.6050e-05
# Epoch 142/500
# 1/1 [==============================] - 0s 7ms/step - loss: 8.4283e-05
# Epoch 143/500
# 1/1 [==============================] - 0s 7ms/step - loss: 8.2553e-05
# Epoch 144/500
# 1/1 [==============================] - 0s 6ms/step - loss: 8.0855e-05
# Epoch 145/500
# 1/1 [==============================] - 0s 7ms/step - loss: 7.9194e-05
# Epoch 146/500
# 1/1 [==============================] - 0s 6ms/step - loss: 7.7569e-05
# Epoch 147/500
# 1/1 [==============================] - 0s 7ms/step - loss: 7.5975e-05
# Epoch 148/500
# 1/1 [==============================] - 0s 6ms/step - loss: 7.4415e-05
# Epoch 149/500
# 1/1 [==============================] - 0s 6ms/step - loss: 7.2885e-05
# Epoch 150/500
# 1/1 [==============================] - 0s 6ms/step - loss: 7.1388e-05
# Epoch 151/500
# 1/1 [==============================] - 0s 6ms/step - loss: 6.9921e-05
# Epoch 152/500
# 1/1 [==============================] - 0s 7ms/step - loss: 6.8485e-05
# Epoch 153/500
# 1/1 [==============================] - 0s 6ms/step - loss: 6.7078e-05
# Epoch 154/500
# 1/1 [==============================] - 0s 7ms/step - loss: 6.5699e-05
# Epoch 155/500
# 1/1 [==============================] - 0s 7ms/step - loss: 6.4349e-05
# Epoch 156/500
# 1/1 [==============================] - 0s 6ms/step - loss: 6.3029e-05
# Epoch 157/500
# 1/1 [==============================] - 0s 7ms/step - loss: 6.1732e-05
# Epoch 158/500
# 1/1 [==============================] - 0s 7ms/step - loss: 6.0466e-05
# Epoch 159/500
# 1/1 [==============================] - 0s 7ms/step - loss: 5.9224e-05
# Epoch 160/500
# 1/1 [==============================] - 0s 6ms/step - loss: 5.8006e-05
# Epoch 161/500
# 1/1 [==============================] - 0s 9ms/step - loss: 5.6816e-05
# Epoch 162/500
# 1/1 [==============================] - 0s 6ms/step - loss: 5.5649e-05
# Epoch 163/500
# 1/1 [==============================] - 0s 7ms/step - loss: 5.4505e-05
# Epoch 164/500
# 1/1 [==============================] - 0s 6ms/step - loss: 5.3386e-05
# Epoch 165/500
# 1/1 [==============================] - 0s 7ms/step - loss: 5.2290e-05
# Epoch 166/500
# 1/1 [==============================] - 0s 7ms/step - loss: 5.1215e-05
# Epoch 167/500
# 1/1 [==============================] - 0s 6ms/step - loss: 5.0163e-05
# Epoch 168/500
# 1/1 [==============================] - 0s 8ms/step - loss: 4.9133e-05
# Epoch 169/500
# 1/1 [==============================] - 0s 8ms/step - loss: 4.8124e-05
# Epoch 170/500
# 1/1 [==============================] - 0s 7ms/step - loss: 4.7136e-05
# Epoch 171/500
# 1/1 [==============================] - 0s 7ms/step - loss: 4.6167e-05
# Epoch 172/500
# 1/1 [==============================] - 0s 7ms/step - loss: 4.5220e-05
# Epoch 173/500
# 1/1 [==============================] - 0s 8ms/step - loss: 4.4290e-05
# Epoch 174/500
# 1/1 [==============================] - 0s 7ms/step - loss: 4.3380e-05
# Epoch 175/500
# 1/1 [==============================] - 0s 6ms/step - loss: 4.2489e-05
# Epoch 176/500
# 1/1 [==============================] - 0s 7ms/step - loss: 4.1617e-05
# Epoch 177/500
# 1/1 [==============================] - 0s 6ms/step - loss: 4.0762e-05
# Epoch 178/500
# 1/1 [==============================] - 0s 6ms/step - loss: 3.9924e-05
# Epoch 179/500
# 1/1 [==============================] - 0s 7ms/step - loss: 3.9105e-05
# Epoch 180/500
# 1/1 [==============================] - 0s 7ms/step - loss: 3.8301e-05
# Epoch 181/500
# 1/1 [==============================] - 0s 7ms/step - loss: 3.7513e-05
# Epoch 182/500
# 1/1 [==============================] - 0s 9ms/step - loss: 3.6743e-05
# Epoch 183/500
# 1/1 [==============================] - 0s 9ms/step - loss: 3.5989e-05
# Epoch 184/500
# 1/1 [==============================] - 0s 8ms/step - loss: 3.5250e-05
# Epoch 185/500
# 1/1 [==============================] - 0s 7ms/step - loss: 3.4526e-05
# Epoch 186/500
# 1/1 [==============================] - 0s 9ms/step - loss: 3.3817e-05
# Epoch 187/500
# 1/1 [==============================] - 0s 9ms/step - loss: 3.3121e-05
# Epoch 188/500
# 1/1 [==============================] - 0s 11ms/step - loss: 3.2442e-05
# Epoch 189/500
# 1/1 [==============================] - 0s 8ms/step - loss: 3.1775e-05
# Epoch 190/500
# 1/1 [==============================] - 0s 9ms/step - loss: 3.1123e-05
# Epoch 191/500
# 1/1 [==============================] - 0s 8ms/step - loss: 3.0484e-05
# Epoch 192/500
# 1/1 [==============================] - 0s 7ms/step - loss: 2.9857e-05
# Epoch 193/500
# 1/1 [==============================] - 0s 8ms/step - loss: 2.9245e-05
# Epoch 194/500
# 1/1 [==============================] - 0s 7ms/step - loss: 2.8644e-05
# Epoch 195/500
# 1/1 [==============================] - 0s 8ms/step - loss: 2.8055e-05
# Epoch 196/500
# 1/1 [==============================] - 0s 8ms/step - loss: 2.7479e-05
# Epoch 197/500
# 1/1 [==============================] - 0s 6ms/step - loss: 2.6914e-05
# Epoch 198/500
# 1/1 [==============================] - 0s 7ms/step - loss: 2.6361e-05
# Epoch 199/500
# 1/1 [==============================] - 0s 7ms/step - loss: 2.5820e-05
# Epoch 200/500
# 1/1 [==============================] - 0s 8ms/step - loss: 2.5290e-05
# Epoch 201/500
# 1/1 [==============================] - 0s 7ms/step - loss: 2.4770e-05
# Epoch 202/500
# 1/1 [==============================] - 0s 5ms/step - loss: 2.4260e-05
# Epoch 203/500
# 1/1 [==============================] - 0s 8ms/step - loss: 2.3763e-05
# Epoch 204/500
# 1/1 [==============================] - 0s 6ms/step - loss: 2.3276e-05
# Epoch 205/500
# 1/1 [==============================] - 0s 7ms/step - loss: 2.2797e-05
# Epoch 206/500
# 1/1 [==============================] - 0s 6ms/step - loss: 2.2329e-05
# Epoch 207/500
# 1/1 [==============================] - 0s 8ms/step - loss: 2.1870e-05
# Epoch 208/500
# 1/1 [==============================] - 0s 7ms/step - loss: 2.1421e-05
# Epoch 209/500
# 1/1 [==============================] - 0s 8ms/step - loss: 2.0981e-05
# Epoch 210/500
# 1/1 [==============================] - 0s 7ms/step - loss: 2.0549e-05
# Epoch 211/500
# 1/1 [==============================] - 0s 6ms/step - loss: 2.0127e-05
# Epoch 212/500
# 1/1 [==============================] - 0s 7ms/step - loss: 1.9714e-05
# Epoch 213/500
# 1/1 [==============================] - 0s 7ms/step - loss: 1.9309e-05
# Epoch 214/500
# 1/1 [==============================] - 0s 9ms/step - loss: 1.8912e-05
# Epoch 215/500
# 1/1 [==============================] - 0s 17ms/step - loss: 1.8524e-05
# Epoch 216/500
# 1/1 [==============================] - 0s 7ms/step - loss: 1.8143e-05
# Epoch 217/500
# 1/1 [==============================] - 0s 7ms/step - loss: 1.7771e-05
# Epoch 218/500
# 1/1 [==============================] - 0s 7ms/step - loss: 1.7406e-05
# Epoch 219/500
# 1/1 [==============================] - 0s 6ms/step - loss: 1.7049e-05
# Epoch 220/500
# 1/1 [==============================] - 0s 7ms/step - loss: 1.6699e-05
# Epoch 221/500
# 1/1 [==============================] - 0s 6ms/step - loss: 1.6356e-05
# Epoch 222/500
# 1/1 [==============================] - 0s 6ms/step - loss: 1.6020e-05
# Epoch 223/500
# 1/1 [==============================] - 0s 6ms/step - loss: 1.5691e-05
# Epoch 224/500
# 1/1 [==============================] - 0s 6ms/step - loss: 1.5369e-05
# Epoch 225/500
# 1/1 [==============================] - 0s 5ms/step - loss: 1.5053e-05
# Epoch 226/500
# 1/1 [==============================] - 0s 6ms/step - loss: 1.4744e-05
# Epoch 227/500
# 1/1 [==============================] - 0s 7ms/step - loss: 1.4441e-05
# Epoch 228/500
# 1/1 [==============================] - 0s 6ms/step - loss: 1.4145e-05
# Epoch 229/500
# 1/1 [==============================] - 0s 7ms/step - loss: 1.3854e-05
# Epoch 230/500
# 1/1 [==============================] - 0s 8ms/step - loss: 1.3569e-05
# Epoch 231/500
# 1/1 [==============================] - 0s 7ms/step - loss: 1.3290e-05
# Epoch 232/500
# 1/1 [==============================] - 0s 6ms/step - loss: 1.3017e-05
# Epoch 233/500
# 1/1 [==============================] - 0s 6ms/step - loss: 1.2750e-05
# Epoch 234/500
# 1/1 [==============================] - 0s 6ms/step - loss: 1.2488e-05
# Epoch 235/500
# 1/1 [==============================] - 0s 6ms/step - loss: 1.2232e-05
# Epoch 236/500
# 1/1 [==============================] - 0s 7ms/step - loss: 1.1980e-05
# Epoch 237/500
# 1/1 [==============================] - 0s 7ms/step - loss: 1.1735e-05
# Epoch 238/500
# 1/1 [==============================] - 0s 7ms/step - loss: 1.1493e-05
# Epoch 239/500
# 1/1 [==============================] - 0s 6ms/step - loss: 1.1258e-05
# Epoch 240/500
# 1/1 [==============================] - 0s 8ms/step - loss: 1.1026e-05
# Epoch 241/500
# 1/1 [==============================] - 0s 8ms/step - loss: 1.0800e-05
# Epoch 242/500
# 1/1 [==============================] - 0s 7ms/step - loss: 1.0578e-05
# Epoch 243/500
# 1/1 [==============================] - 0s 6ms/step - loss: 1.0361e-05
# Epoch 244/500
# 1/1 [==============================] - 0s 6ms/step - loss: 1.0148e-05
# Epoch 245/500
# 1/1 [==============================] - 0s 6ms/step - loss: 9.9390e-06
# Epoch 246/500
# 1/1 [==============================] - 0s 6ms/step - loss: 9.7356e-06
# Epoch 247/500
# 1/1 [==============================] - 0s 7ms/step - loss: 9.5355e-06
# Epoch 248/500
# 1/1 [==============================] - 0s 6ms/step - loss: 9.3398e-06
# Epoch 249/500
# 1/1 [==============================] - 0s 6ms/step - loss: 9.1474e-06
# Epoch 250/500
# 1/1 [==============================] - 0s 7ms/step - loss: 8.9598e-06
# Epoch 251/500
# 1/1 [==============================] - 0s 7ms/step - loss: 8.7757e-06
# Epoch 252/500
# 1/1 [==============================] - 0s 8ms/step - loss: 8.5954e-06
# Epoch 253/500
# 1/1 [==============================] - 0s 8ms/step - loss: 8.4188e-06
# Epoch 254/500
# 1/1 [==============================] - 0s 10ms/step - loss: 8.2452e-06
# Epoch 255/500
# 1/1 [==============================] - 0s 7ms/step - loss: 8.0767e-06
# Epoch 256/500
# 1/1 [==============================] - 0s 7ms/step - loss: 7.9103e-06
# Epoch 257/500
# 1/1 [==============================] - 0s 7ms/step - loss: 7.7484e-06
# Epoch 258/500
# 1/1 [==============================] - 0s 6ms/step - loss: 7.5892e-06
# Epoch 259/500
# 1/1 [==============================] - 0s 7ms/step - loss: 7.4332e-06
# Epoch 260/500
# 1/1 [==============================] - 0s 7ms/step - loss: 7.2802e-06
# Epoch 261/500
# 1/1 [==============================] - 0s 6ms/step - loss: 7.1305e-06
# Epoch 262/500
# 1/1 [==============================] - 0s 6ms/step - loss: 6.9842e-06
# Epoch 263/500
# 1/1 [==============================] - 0s 6ms/step - loss: 6.8411e-06
# Epoch 264/500
# 1/1 [==============================] - 0s 7ms/step - loss: 6.7008e-06
# Epoch 265/500
# 1/1 [==============================] - 0s 8ms/step - loss: 6.5629e-06
# Epoch 266/500
# 1/1 [==============================] - 0s 7ms/step - loss: 6.4276e-06
# Epoch 267/500
# 1/1 [==============================] - 0s 7ms/step - loss: 6.2958e-06
# Epoch 268/500
# 1/1 [==============================] - 0s 7ms/step - loss: 6.1663e-06
# Epoch 269/500
# 1/1 [==============================] - 0s 7ms/step - loss: 6.0392e-06
# Epoch 270/500
# 1/1 [==============================] - 0s 7ms/step - loss: 5.9155e-06
# Epoch 271/500
# 1/1 [==============================] - 0s 6ms/step - loss: 5.7942e-06
# Epoch 272/500
# 1/1 [==============================] - 0s 8ms/step - loss: 5.6750e-06
# Epoch 273/500
# 1/1 [==============================] - 0s 7ms/step - loss: 5.5581e-06
# Epoch 274/500
# 1/1 [==============================] - 0s 7ms/step - loss: 5.4441e-06
# Epoch 275/500
# 1/1 [==============================] - 0s 6ms/step - loss: 5.3321e-06
# Epoch 276/500
# 1/1 [==============================] - 0s 6ms/step - loss: 5.2225e-06
# Epoch 277/500
# 1/1 [==============================] - 0s 8ms/step - loss: 5.1156e-06
# Epoch 278/500
# 1/1 [==============================] - 0s 6ms/step - loss: 5.0105e-06
# Epoch 279/500
# 1/1 [==============================] - 0s 6ms/step - loss: 4.9073e-06
# Epoch 280/500
# 1/1 [==============================] - 0s 7ms/step - loss: 4.8067e-06
# Epoch 281/500
# 1/1 [==============================] - 0s 6ms/step - loss: 4.7081e-06
# Epoch 282/500
# 1/1 [==============================] - 0s 6ms/step - loss: 4.6112e-06
# Epoch 283/500
# 1/1 [==============================] - 0s 7ms/step - loss: 4.5165e-06
# Epoch 284/500
# 1/1 [==============================] - 0s 8ms/step - loss: 4.4238e-06
# Epoch 285/500
# 1/1 [==============================] - 0s 6ms/step - loss: 4.3326e-06
# Epoch 286/500
# 1/1 [==============================] - 0s 7ms/step - loss: 4.2434e-06
# Epoch 287/500
# 1/1 [==============================] - 0s 7ms/step - loss: 4.1561e-06
# Epoch 288/500
# 1/1 [==============================] - 0s 7ms/step - loss: 4.0706e-06
# Epoch 289/500
# 1/1 [==============================] - 0s 7ms/step - loss: 3.9869e-06
# Epoch 290/500
# 1/1 [==============================] - 0s 7ms/step - loss: 3.9053e-06
# Epoch 291/500
# 1/1 [==============================] - 0s 8ms/step - loss: 3.8251e-06
# Epoch 292/500
# 1/1 [==============================] - 0s 8ms/step - loss: 3.7462e-06
# Epoch 293/500
# 1/1 [==============================] - 0s 6ms/step - loss: 3.6697e-06
# Epoch 294/500
# 1/1 [==============================] - 0s 7ms/step - loss: 3.5941e-06
# Epoch 295/500
# 1/1 [==============================] - 0s 7ms/step - loss: 3.5204e-06
# Epoch 296/500
# 1/1 [==============================] - 0s 6ms/step - loss: 3.4481e-06
# Epoch 297/500
# 1/1 [==============================] - 0s 6ms/step - loss: 3.3773e-06
# Epoch 298/500
# 1/1 [==============================] - 0s 7ms/step - loss: 3.3079e-06
# Epoch 299/500
# 1/1 [==============================] - 0s 6ms/step - loss: 3.2400e-06
# Epoch 300/500
# 1/1 [==============================] - 0s 13ms/step - loss: 3.1736e-06
# Epoch 301/500
# 1/1 [==============================] - 0s 29ms/step - loss: 3.1080e-06
# Epoch 302/500
# 1/1 [==============================] - 0s 7ms/step - loss: 3.0440e-06
# Epoch 303/500
# 1/1 [==============================] - 0s 6ms/step - loss: 2.9816e-06
# Epoch 304/500
# 1/1 [==============================] - 0s 7ms/step - loss: 2.9205e-06
# Epoch 305/500
# 1/1 [==============================] - 0s 6ms/step - loss: 2.8605e-06
# Epoch 306/500
# 1/1 [==============================] - 0s 7ms/step - loss: 2.8017e-06
# Epoch 307/500
# 1/1 [==============================] - 0s 9ms/step - loss: 2.7441e-06
# Epoch 308/500
# 1/1 [==============================] - 0s 8ms/step - loss: 2.6878e-06
# Epoch 309/500
# 1/1 [==============================] - 0s 7ms/step - loss: 2.6326e-06
# Epoch 310/500
# 1/1 [==============================] - 0s 7ms/step - loss: 2.5785e-06
# Epoch 311/500
# 1/1 [==============================] - 0s 6ms/step - loss: 2.5256e-06
# Epoch 312/500
# 1/1 [==============================] - 0s 6ms/step - loss: 2.4737e-06
# Epoch 313/500
# 1/1 [==============================] - 0s 6ms/step - loss: 2.4230e-06
# Epoch 314/500
# 1/1 [==============================] - 0s 6ms/step - loss: 2.3730e-06
# Epoch 315/500
# 1/1 [==============================] - 0s 6ms/step - loss: 2.3243e-06
# Epoch 316/500
# 1/1 [==============================] - 0s 6ms/step - loss: 2.2765e-06
# Epoch 317/500
# 1/1 [==============================] - 0s 6ms/step - loss: 2.2299e-06
# Epoch 318/500
# 1/1 [==============================] - 0s 7ms/step - loss: 2.1840e-06
# Epoch 319/500
# 1/1 [==============================] - 0s 7ms/step - loss: 2.1390e-06
# Epoch 320/500
# 1/1 [==============================] - 0s 8ms/step - loss: 2.0950e-06
# Epoch 321/500
# 1/1 [==============================] - 0s 7ms/step - loss: 2.0521e-06
# Epoch 322/500
# 1/1 [==============================] - 0s 6ms/step - loss: 2.0101e-06
# Epoch 323/500
# 1/1 [==============================] - 0s 7ms/step - loss: 1.9689e-06
# Epoch 324/500
# 1/1 [==============================] - 0s 7ms/step - loss: 1.9283e-06
# Epoch 325/500
# 1/1 [==============================] - 0s 6ms/step - loss: 1.8885e-06
# Epoch 326/500
# 1/1 [==============================] - 0s 6ms/step - loss: 1.8500e-06
# Epoch 327/500
# 1/1 [==============================] - 0s 5ms/step - loss: 1.8119e-06
# Epoch 328/500
# 1/1 [==============================] - 0s 6ms/step - loss: 1.7749e-06
# Epoch 329/500
# 1/1 [==============================] - 0s 7ms/step - loss: 1.7383e-06
# Epoch 330/500
# 1/1 [==============================] - 0s 6ms/step - loss: 1.7025e-06
# Epoch 331/500
# 1/1 [==============================] - 0s 7ms/step - loss: 1.6676e-06
# Epoch 332/500
# 1/1 [==============================] - 0s 6ms/step - loss: 1.6335e-06
# Epoch 333/500
# 1/1 [==============================] - 0s 8ms/step - loss: 1.5997e-06
# Epoch 334/500
# 1/1 [==============================] - 0s 7ms/step - loss: 1.5671e-06
# Epoch 335/500
# 1/1 [==============================] - 0s 5ms/step - loss: 1.5348e-06
# Epoch 336/500
# 1/1 [==============================] - 0s 7ms/step - loss: 1.5033e-06
# Epoch 337/500
# 1/1 [==============================] - 0s 7ms/step - loss: 1.4726e-06
# Epoch 338/500
# 1/1 [==============================] - 0s 7ms/step - loss: 1.4421e-06
# Epoch 339/500
# 1/1 [==============================] - 0s 7ms/step - loss: 1.4127e-06
# Epoch 340/500
# 1/1 [==============================] - 0s 8ms/step - loss: 1.3835e-06
# Epoch 341/500
# 1/1 [==============================] - 0s 6ms/step - loss: 1.3552e-06
# Epoch 342/500
# 1/1 [==============================] - 0s 7ms/step - loss: 1.3274e-06
# Epoch 343/500
# 1/1 [==============================] - 0s 6ms/step - loss: 1.3001e-06
# Epoch 344/500
# 1/1 [==============================] - 0s 7ms/step - loss: 1.2733e-06
# Epoch 345/500
# 1/1 [==============================] - 0s 6ms/step - loss: 1.2473e-06
# Epoch 346/500
# 1/1 [==============================] - 0s 7ms/step - loss: 1.2216e-06
# Epoch 347/500
# 1/1 [==============================] - 0s 6ms/step - loss: 1.1964e-06
# Epoch 348/500
# 1/1 [==============================] - 0s 7ms/step - loss: 1.1717e-06
# Epoch 349/500
# 1/1 [==============================] - 0s 9ms/step - loss: 1.1477e-06
# Epoch 350/500
# 1/1 [==============================] - 0s 8ms/step - loss: 1.1242e-06
# Epoch 351/500
# 1/1 [==============================] - 0s 7ms/step - loss: 1.1010e-06
# Epoch 352/500
# 1/1 [==============================] - 0s 8ms/step - loss: 1.0784e-06
# Epoch 353/500
# 1/1 [==============================] - 0s 7ms/step - loss: 1.0562e-06
# Epoch 354/500
# 1/1 [==============================] - 0s 43ms/step - loss: 1.0346e-06
# Epoch 355/500
# 1/1 [==============================] - 0s 7ms/step - loss: 1.0134e-06
# Epoch 356/500
# 1/1 [==============================] - 0s 7ms/step - loss: 9.9246e-07
# Epoch 357/500
# 1/1 [==============================] - 0s 7ms/step - loss: 9.7208e-07
# Epoch 358/500
# 1/1 [==============================] - 0s 7ms/step - loss: 9.5236e-07
# Epoch 359/500
# 1/1 [==============================] - 0s 8ms/step - loss: 9.3280e-07
# Epoch 360/500
# 1/1 [==============================] - 0s 6ms/step - loss: 9.1338e-07
# Epoch 361/500
# 1/1 [==============================] - 0s 6ms/step - loss: 8.9463e-07
# Epoch 362/500
# 1/1 [==============================] - 0s 7ms/step - loss: 8.7640e-07
# Epoch 363/500
# 1/1 [==============================] - 0s 6ms/step - loss: 8.5831e-07
# Epoch 364/500
# 1/1 [==============================] - 0s 8ms/step - loss: 8.4068e-07
# Epoch 365/500
# 1/1 [==============================] - 0s 7ms/step - loss: 8.2352e-07
# Epoch 366/500
# 1/1 [==============================] - 0s 7ms/step - loss: 8.0661e-07
# Epoch 367/500
# 1/1 [==============================] - 0s 6ms/step - loss: 7.9010e-07
# Epoch 368/500
# 1/1 [==============================] - 0s 8ms/step - loss: 7.7378e-07
# Epoch 369/500
# 1/1 [==============================] - 0s 7ms/step - loss: 7.5804e-07
# Epoch 370/500
# 1/1 [==============================] - 0s 7ms/step - loss: 7.4235e-07
# Epoch 371/500
# 1/1 [==============================] - 0s 8ms/step - loss: 7.2709e-07
# Epoch 372/500
# 1/1 [==============================] - 0s 7ms/step - loss: 7.1226e-07
# Epoch 373/500
# 1/1 [==============================] - 0s 7ms/step - loss: 6.9748e-07
# Epoch 374/500
# 1/1 [==============================] - 0s 6ms/step - loss: 6.8317e-07
# Epoch 375/500
# 1/1 [==============================] - 0s 7ms/step - loss: 6.6931e-07
# Epoch 376/500
# 1/1 [==============================] - 0s 8ms/step - loss: 6.5555e-07
# Epoch 377/500
# 1/1 [==============================] - 0s 6ms/step - loss: 6.4193e-07
# Epoch 378/500
# 1/1 [==============================] - 0s 8ms/step - loss: 6.2894e-07
# Epoch 379/500
# 1/1 [==============================] - 0s 7ms/step - loss: 6.1586e-07
# Epoch 380/500
# 1/1 [==============================] - 0s 7ms/step - loss: 6.0318e-07
# Epoch 381/500
# 1/1 [==============================] - 0s 7ms/step - loss: 5.9069e-07
# Epoch 382/500
# 1/1 [==============================] - 0s 7ms/step - loss: 5.7860e-07
# Epoch 383/500
# 1/1 [==============================] - 0s 8ms/step - loss: 5.6689e-07
# Epoch 384/500
# 1/1 [==============================] - 0s 7ms/step - loss: 5.5525e-07
# Epoch 385/500
# 1/1 [==============================] - 0s 6ms/step - loss: 5.4378e-07
# Epoch 386/500
# 1/1 [==============================] - 0s 6ms/step - loss: 5.3259e-07
# Epoch 387/500
# 1/1 [==============================] - 0s 7ms/step - loss: 5.2177e-07
# Epoch 388/500
# 1/1 [==============================] - 0s 7ms/step - loss: 5.1109e-07
# Epoch 389/500
# 1/1 [==============================] - 0s 7ms/step - loss: 5.0057e-07
# Epoch 390/500
# 1/1 [==============================] - 0s 7ms/step - loss: 4.9032e-07
# Epoch 391/500
# 1/1 [==============================] - 0s 6ms/step - loss: 4.8020e-07
# Epoch 392/500
# 1/1 [==============================] - 0s 7ms/step - loss: 4.7030e-07
# Epoch 393/500
# 1/1 [==============================] - 0s 6ms/step - loss: 4.6066e-07
# Epoch 394/500
# 1/1 [==============================] - 0s 6ms/step - loss: 4.5120e-07
# Epoch 395/500
# 1/1 [==============================] - 0s 6ms/step - loss: 4.4207e-07
# Epoch 396/500
# 1/1 [==============================] - 0s 6ms/step - loss: 4.3301e-07
# Epoch 397/500
# 1/1 [==============================] - 0s 8ms/step - loss: 4.2412e-07
# Epoch 398/500
# 1/1 [==============================] - 0s 6ms/step - loss: 4.1530e-07
# Epoch 399/500
# 1/1 [==============================] - 0s 7ms/step - loss: 4.0689e-07
# Epoch 400/500
# 1/1 [==============================] - 0s 6ms/step - loss: 3.9848e-07
# Epoch 401/500
# 1/1 [==============================] - 0s 8ms/step - loss: 3.9025e-07
# Epoch 402/500
# 1/1 [==============================] - 0s 7ms/step - loss: 3.8223e-07
# Epoch 403/500
# 1/1 [==============================] - 0s 9ms/step - loss: 3.7433e-07
# Epoch 404/500
# 1/1 [==============================] - 0s 25ms/step - loss: 3.6668e-07
# Epoch 405/500
# 1/1 [==============================] - 0s 7ms/step - loss: 3.5929e-07
# Epoch 406/500
# 1/1 [==============================] - 0s 7ms/step - loss: 3.5194e-07
# Epoch 407/500
# 1/1 [==============================] - 0s 8ms/step - loss: 3.4462e-07
# Epoch 408/500
# 1/1 [==============================] - 0s 6ms/step - loss: 3.3759e-07
# Epoch 409/500
# 1/1 [==============================] - 0s 6ms/step - loss: 3.3066e-07
# Epoch 410/500
# 1/1 [==============================] - 0s 7ms/step - loss: 3.2391e-07
# Epoch 411/500
# 1/1 [==============================] - 0s 7ms/step - loss: 3.1718e-07
# Epoch 412/500
# 1/1 [==============================] - 0s 6ms/step - loss: 3.1069e-07
# Epoch 413/500
# 1/1 [==============================] - 0s 8ms/step - loss: 3.0432e-07
# Epoch 414/500
# 1/1 [==============================] - 0s 6ms/step - loss: 2.9809e-07
# Epoch 415/500
# 1/1 [==============================] - 0s 6ms/step - loss: 2.9194e-07
# Epoch 416/500
# 1/1 [==============================] - 0s 7ms/step - loss: 2.8594e-07
# Epoch 417/500
# 1/1 [==============================] - 0s 8ms/step - loss: 2.8005e-07
# Epoch 418/500
# 1/1 [==============================] - 0s 8ms/step - loss: 2.7437e-07
# Epoch 419/500
# 1/1 [==============================] - 0s 7ms/step - loss: 2.6869e-07
# Epoch 420/500
# 1/1 [==============================] - 0s 6ms/step - loss: 2.6309e-07
# Epoch 421/500
# 1/1 [==============================] - 0s 7ms/step - loss: 2.5778e-07
# Epoch 422/500
# 1/1 [==============================] - 0s 7ms/step - loss: 2.5253e-07
# Epoch 423/500
# 1/1 [==============================] - 0s 6ms/step - loss: 2.4735e-07
# Epoch 424/500
# 1/1 [==============================] - 0s 6ms/step - loss: 2.4230e-07
# Epoch 425/500
# 1/1 [==============================] - 0s 8ms/step - loss: 2.3725e-07
# Epoch 426/500
# 1/1 [==============================] - 0s 9ms/step - loss: 2.3237e-07
# Epoch 427/500
# 1/1 [==============================] - 0s 7ms/step - loss: 2.2766e-07
# Epoch 428/500
# 1/1 [==============================] - 0s 7ms/step - loss: 2.2295e-07
# Epoch 429/500
# 1/1 [==============================] - 0s 7ms/step - loss: 2.1837e-07
# Epoch 430/500
# 1/1 [==============================] - 0s 6ms/step - loss: 2.1397e-07
# Epoch 431/500
# 1/1 [==============================] - 0s 7ms/step - loss: 2.0949e-07
# Epoch 432/500
# 1/1 [==============================] - 0s 7ms/step - loss: 2.0523e-07
# Epoch 433/500
# 1/1 [==============================] - 0s 6ms/step - loss: 2.0104e-07
# Epoch 434/500
# 1/1 [==============================] - 0s 5ms/step - loss: 1.9692e-07
# Epoch 435/500
# 1/1 [==============================] - 0s 6ms/step - loss: 1.9290e-07
# Epoch 436/500
# 1/1 [==============================] - 0s 6ms/step - loss: 1.8883e-07
# Epoch 437/500
# 1/1 [==============================] - 0s 7ms/step - loss: 1.8509e-07
# Epoch 438/500
# 1/1 [==============================] - 0s 8ms/step - loss: 1.8124e-07
# Epoch 439/500
# 1/1 [==============================] - 0s 6ms/step - loss: 1.7755e-07
# Epoch 440/500
# 1/1 [==============================] - 0s 6ms/step - loss: 1.7382e-07
# Epoch 441/500
# 1/1 [==============================] - 0s 6ms/step - loss: 1.7023e-07
# Epoch 442/500
# 1/1 [==============================] - 0s 6ms/step - loss: 1.6677e-07
# Epoch 443/500
# 1/1 [==============================] - 0s 5ms/step - loss: 1.6330e-07
# Epoch 444/500
# 1/1 [==============================] - 0s 6ms/step - loss: 1.5998e-07
# Epoch 445/500
# 1/1 [==============================] - 0s 6ms/step - loss: 1.5668e-07
# Epoch 446/500
# 1/1 [==============================] - 0s 6ms/step - loss: 1.5344e-07
# Epoch 447/500
# 1/1 [==============================] - 0s 6ms/step - loss: 1.5036e-07
# Epoch 448/500
# 1/1 [==============================] - 0s 6ms/step - loss: 1.4720e-07
# Epoch 449/500
# 1/1 [==============================] - 0s 6ms/step - loss: 1.4428e-07
# Epoch 450/500
# 1/1 [==============================] - 0s 6ms/step - loss: 1.4128e-07
# Epoch 451/500
# 1/1 [==============================] - 0s 6ms/step - loss: 1.3832e-07
# Epoch 452/500
# 1/1 [==============================] - 0s 7ms/step - loss: 1.3555e-07
# Epoch 453/500
# 1/1 [==============================] - 0s 6ms/step - loss: 1.3275e-07
# Epoch 454/500
# 1/1 [==============================] - 0s 6ms/step - loss: 1.3002e-07
# Epoch 455/500
# 1/1 [==============================] - 0s 6ms/step - loss: 1.2728e-07
# Epoch 456/500
# 1/1 [==============================] - 0s 6ms/step - loss: 1.2468e-07
# Epoch 457/500
# 1/1 [==============================] - 0s 7ms/step - loss: 1.2216e-07
# Epoch 458/500
# 1/1 [==============================] - 0s 6ms/step - loss: 1.1968e-07
# Epoch 459/500
# 1/1 [==============================] - 0s 7ms/step - loss: 1.1719e-07
# Epoch 460/500
# 1/1 [==============================] - 0s 6ms/step - loss: 1.1476e-07
# Epoch 461/500
# 1/1 [==============================] - 0s 7ms/step - loss: 1.1244e-07
# Epoch 462/500
# 1/1 [==============================] - 0s 7ms/step - loss: 1.1018e-07
# Epoch 463/500
# 1/1 [==============================] - 0s 6ms/step - loss: 1.0785e-07
# Epoch 464/500
# 1/1 [==============================] - 0s 7ms/step - loss: 1.0572e-07
# Epoch 465/500
# 1/1 [==============================] - 0s 7ms/step - loss: 1.0351e-07
# Epoch 466/500
# 1/1 [==============================] - 0s 7ms/step - loss: 1.0141e-07
# Epoch 467/500
# 1/1 [==============================] - 0s 5ms/step - loss: 9.9260e-08
# Epoch 468/500
# 1/1 [==============================] - 0s 7ms/step - loss: 9.7237e-08
# Epoch 469/500
# 1/1 [==============================] - 0s 6ms/step - loss: 9.5275e-08
# Epoch 470/500
# 1/1 [==============================] - 0s 6ms/step - loss: 9.3306e-08
# Epoch 471/500
# 1/1 [==============================] - 0s 6ms/step - loss: 9.1419e-08
# Epoch 472/500
# 1/1 [==============================] - 0s 5ms/step - loss: 8.9470e-08
# Epoch 473/500
# 1/1 [==============================] - 0s 6ms/step - loss: 8.7692e-08
# Epoch 474/500
# 1/1 [==============================] - 0s 6ms/step - loss: 8.5852e-08
# Epoch 475/500
# 1/1 [==============================] - 0s 34ms/step - loss: 8.4095e-08
# Epoch 476/500
# 1/1 [==============================] - 0s 7ms/step - loss: 8.2395e-08
# Epoch 477/500
# 1/1 [==============================] - 0s 6ms/step - loss: 8.0712e-08
# Epoch 478/500
# 1/1 [==============================] - 0s 7ms/step - loss: 7.9079e-08
# Epoch 479/500
# 1/1 [==============================] - 0s 5ms/step - loss: 7.7473e-08
# Epoch 480/500
# 1/1 [==============================] - 0s 6ms/step - loss: 7.5884e-08
# Epoch 481/500
# 1/1 [==============================] - 0s 7ms/step - loss: 7.4316e-08
# Epoch 482/500
# 1/1 [==============================] - 0s 6ms/step - loss: 7.2800e-08
# Epoch 483/500
# 1/1 [==============================] - 0s 8ms/step - loss: 7.1294e-08
# Epoch 484/500
# 1/1 [==============================] - 0s 6ms/step - loss: 6.9846e-08
# Epoch 485/500
# 1/1 [==============================] - 0s 7ms/step - loss: 6.8420e-08
# Epoch 486/500
# 1/1 [==============================] - 0s 7ms/step - loss: 6.7025e-08
# Epoch 487/500
# 1/1 [==============================] - 0s 7ms/step - loss: 6.5626e-08
# Epoch 488/500
# 1/1 [==============================] - 0s 7ms/step - loss: 6.4250e-08
# Epoch 489/500
# 1/1 [==============================] - 0s 6ms/step - loss: 6.2965e-08
# Epoch 490/500
# 1/1 [==============================] - 0s 6ms/step - loss: 6.1622e-08
# Epoch 491/500
# 1/1 [==============================] - 0s 6ms/step - loss: 6.0372e-08
# Epoch 492/500
# 1/1 [==============================] - 0s 6ms/step - loss: 5.9116e-08
# Epoch 493/500
# 1/1 [==============================] - 0s 6ms/step - loss: 5.7923e-08
# Epoch 494/500
# 1/1 [==============================] - 0s 7ms/step - loss: 5.6723e-08
# Epoch 495/500
# 1/1 [==============================] - 0s 5ms/step - loss: 5.5610e-08
# Epoch 496/500
# 1/1 [==============================] - 0s 6ms/step - loss: 5.4441e-08
# Epoch 497/500
# 1/1 [==============================] - 0s 6ms/step - loss: 5.3338e-08
# Epoch 498/500
# 1/1 [==============================] - 0s 8ms/step - loss: 5.2289e-08
# Epoch 499/500
# 1/1 [==============================] - 0s 7ms/step - loss: 5.1215e-08
# Epoch 500/500
# 1/1 [==============================] - 0s 6ms/step - loss: 5.0168e-08

# %% [markdown]
# Ok, now you have a model that has been trained to learn the relationshop between X and Y. You can use the **model.predict** method to have it figure out the Y for a previously unknown X. So, for example, if X = 10, what do you think Y will be? Take a guess before you run this code:

# %%
print(model.predict([10.0]))
# Out:
# 1/1 [==============================] - 0s 263ms/step
# [[31.000658]]

# %% [markdown]
# You might have thought 31, right? But it ended up being a little over. Why do you think that is?
#
# Remember that neural networks deal with probabilities, so given the data that we fed the NN with, it calculated that there is a very high probability that the relationship between X and Y is Y=3X+1, but with only 6 data points we can't know for sure. As a result, the result for 10 is very close to 31, but not necessarily 31.
#
# As you work with neural networks, you'll see this pattern recurring. You will almost always deal with probabilities, not certainties, and will do a little bit of coding to figure out what the result is based on the probabilities, particularly when it comes to classification.
#
# [Introduction to Computer Vision .ipynb]()

# %%
print(model.predict([11.0]))
# Out:
# 1/1 [==============================] - 0s 96ms/step
# [[34.00075]]
